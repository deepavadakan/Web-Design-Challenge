# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/cities.csv",index_col="City ID")
df.to_html("cities.html")
df
# Out:
#      City ID                   City Country    Lat     Lng  Max Temp  \
# 0          0                tikapur      NP  28.50   81.13     78.01
# 1          1                kavieng      PG  -2.57  150.80     82.04
# 2          2              busselton      AU -33.65  115.33     55.99
# 3          3             launceston      AU -41.45  147.17     44.60
# 4          4                   lebu      CL -37.62  -73.65     58.48
# ..       ...                    ...     ...    ...     ...       ...
# 591      591                 itoman      JP  26.12  127.67     78.80
# 592      592                 kiunga      PG  -6.12  141.29     73.26
# 593      593  verkhnyaya maksakovka      RU  61.63   50.97     32.00
# 594      594               akcaabat      TR  41.02   39.57     71.60
# 595      595                   lasa      IT  46.62   10.70     59.00
#
#      Humidity  Cloudiness  Wind Speed        Date
# 0          95           0        3.00  1602856784
# ...
